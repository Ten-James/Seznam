# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
tab = pd.read_csv("pokemon.csv")

# %%
tab
# Out:
#       id         name  height  weight   color      shape  is baby    type 1  \
# 0      1    bulbasaur     0.7     6.9   green  quadruped    False     Grass
# 1      2      ivysaur     1.0    13.0   green  quadruped    False     Grass
# 2      3     venusaur     2.0   100.0   green  quadruped    False     Grass
# 3      4   charmander     0.6     8.5     red    upright    False      Fire
# 4      5   charmeleon     1.1    19.0     red    upright    False      Fire
# ..   ...          ...     ...     ...     ...        ...      ...       ...
# 802  803      poipole     0.6     1.8  purple    upright    False    Poison
# 803  804    naganadel     3.6   150.0  purple      wings    False    Poison
# 804  805    stakataka     5.5   820.0    gray  quadruped    False      Rock
# 805  806  blacephalon     1.8    13.0   white   humanoid    False      Fire
# 806  807      zeraora     1.5    44.5  yellow   humanoid    False  Electric
#
#      type 2  hp  attack  defense  speed
# ...

# %%
deti = tab["is baby"]
deti
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 802    False
# 803    False
# 804    False
# 805    False
# 806    False
# Name: is baby, Length: 807, dtype: bool

# %%
deti.name
# Out:
# 'is baby'

# %%
tab.index
# Out:
# RangeIndex(start=0, stop=807, step=1)

# %%
pok = tab.set_index("is baby").sort_index(ascending = False);
pok
# Out:
#           id      name  height  weight   color     shape    type 1   type 2  \
# is baby
# True     440   happiny     0.6    24.4    pink  humanoid    Normal      NaN
# True     458   mantyke     1.0    65.0    blue     wings     Water   Flying
# True     238  smoochum     0.4     6.0    pink  humanoid       Ice  Psychic
# True     239    elekid     0.6    23.5  yellow  humanoid  Electric      NaN
# True     439   mime-jr     0.6    13.0    pink  humanoid   Psychic    Fairy
# ...      ...       ...     ...     ...     ...       ...       ...      ...
# False    276   taillow     0.3     2.3    blue     wings    Normal   Flying
# False    277   swellow     0.7    19.8    blue     wings    Normal   Flying
# False    278   wingull     0.6     9.5   white     wings     Water   Flying
# False    279  pelipper     1.2    28.0  yellow     wings     Water   Flying
# False    807   zeraora     1.5    44.5  yellow  humanoid  Electric      NaN
#
#           hp  attack  defense  speed
# is baby
# ...

# %%
jendeti = pok.filter(like="True", axis=0)
jendeti
# Out:
#           id       name  height  weight   color      shape    type 1   type 2  \
# is baby
# True     440    happiny     0.6    24.4    pink   humanoid    Normal      NaN
# True     458    mantyke     1.0    65.0    blue      wings     Water   Flying
# True     238   smoochum     0.4     6.0    pink   humanoid       Ice  Psychic
# True     239     elekid     0.6    23.5  yellow   humanoid  Electric      NaN
# True     439    mime-jr     0.6    13.0    pink   humanoid   Psychic    Fairy
# True     438     bonsly     0.5    15.0   brown       legs      Rock      NaN
# True     446   munchlax     0.6   105.0   black   humanoid    Normal      NaN
# True     447      riolu     0.7    20.2    blue    upright  Fighting      NaN
# True     175     togepi     0.3     1.5   white   humanoid     Fairy      NaN
# True     174  igglybuff     0.3     1.0    pink   humanoid    Normal    Fairy
# True     433  chingling     0.2     0.6  yellow   humanoid   Psychic      NaN
# ...
